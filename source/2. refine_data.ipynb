# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
from glob import glob
import numpy as np

# %% [markdown]
# ### 운전자성별

# %%
#지역 변수 선언
region_list = ["서울", "부산", "대구", "인천", "광주", "대전", "울산", "세종", "경기", "강원", "충북", "충남", "전북", "전남", "경북", "경남", "제주" ]
detail = "성별"

for region in region_list:
    acc1_files = glob(f"cardata/{detail}/{region}/교통사고 지표 현황*xls")
    tmp_raw = []

    for name in acc1_files:
        tmp = pd.read_excel(name, header = 1,usecols=[0, 1, 2, 3, 4, 8])
        tmp_raw.append(tmp)

    acc1_raw = pd.concat(tmp_raw)

    acc1_raw.rename(columns={'지자체': '구'}, inplace=True)
    acc1_raw.rename(columns={'운전자성별': '성별'}, inplace=True)

    acc1_raw = acc1_raw.dropna() #결측치 삭제

    acc1_raw['연도'] = acc1_raw['연도'].astype(str).str.split('.').str[0] #연도 str화
    

    # 피봇 테이블 직전 버전
    acc1_raw.to_excel(f"정제/{region}_운전자{detail}_raw.xlsx") 

    acc1 = acc1_raw.pivot_table( index = ["시도", "구", "연도"], columns = f"{detail}", values=['발생건수', '사망자수'], aggfunc = np.sum)
    acc1

    #평탄화 작업
    new_columns = []

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('발생_'+acc1.columns[num][1])

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('사망_'+acc1.columns[num][1])

    acc1.columns = new_columns

    acc1.reset_index(inplace=True)

    # 최종 버전
    acc1.to_excel(f"정제/{region}_운전자{detail}.xlsx")

# %% [markdown]
# ### 연령대

# %%
#지역 변수 선언
region_list = ["서울", "부산", "대구", "인천", "광주", "대전", "울산", "세종", "경기", "강원", "충북", "충남", "전북", "전남", "경북", "경남", "제주" ]
detail = "연령대"

for region in region_list:
    acc1_files = glob(f"cardata/{detail}/{region}/교통사고 지표 현황*xls")
    tmp_raw = []

    for name in acc1_files:
        tmp = pd.read_excel(name, header = 1,usecols=[0, 1, 2, 3, 4, 8])
        tmp_raw.append(tmp)

    acc1_raw = pd.concat(tmp_raw)

    acc1_raw.rename(columns={'지자체': '구'}, inplace=True)

    acc1_raw = acc1_raw.dropna() #결측치 삭제

    acc1_raw['연도'] = acc1_raw['연도'].astype(str).str.split('.').str[0] #연도 str화
    

    # 피봇 테이블 직전 버전
    acc1_raw.to_excel(f"정제/{region}_{detail}_raw.xlsx") 

    acc1 = acc1_raw.pivot_table( index = ["시도", "구", "연도"], columns = f"{detail}", values=['발생건수', '사망자수'], aggfunc = np.sum)
    acc1

    #평탄화 작업
    new_columns = []

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('발생_'+acc1.columns[num][1])

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('사망_'+acc1.columns[num][1])

    acc1.columns = new_columns

    acc1.reset_index(inplace=True)

    # 최종 버전
    acc1.to_excel(f"정제/{region}_{detail}.xlsx")

# %% [markdown]
# ### 운전경력

# %%
#지역 변수 선언
region_list = ["서울", "부산", "대구", "인천", "광주", "대전", "울산", "세종", "경기", "강원", "충북", "충남", "전북", "전남", "경북", "경남", "제주" ]
detail = "운전경력"

for region in region_list:
    acc1_files = glob(f"cardata/{detail}/{region}/교통사고 지표 현황*xls")
    tmp_raw = []

    for name in acc1_files:
        tmp = pd.read_excel(name, header = 1,usecols=[0, 1, 2, 3, 4, 8])
        tmp_raw.append(tmp)

    acc1_raw = pd.concat(tmp_raw)

    acc1_raw.rename(columns={'지자체': '구'}, inplace=True)

    acc1_raw = acc1_raw.dropna() #결측치 삭제

    acc1_raw['연도'] = acc1_raw['연도'].astype(str).str.split('.').str[0] #연도 str화
    

    # 피봇 테이블 직전 버전
    acc1_raw.to_excel(f"정제/{region}_{detail}_raw.xlsx") 

    acc1 = acc1_raw.pivot_table( index = ["시도", "구", "연도"], columns = f"{detail}", values=['발생건수', '사망자수'], aggfunc = np.sum)
    acc1

    #평탄화 작업
    new_columns = []

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('발생_'+acc1.columns[num][1])

    for num in range(int(len(acc1.columns)/2)):
        new_columns.append('사망_'+acc1.columns[num][1])

    acc1.columns = new_columns

    acc1.reset_index(inplace=True)

    # 최종 버전
    acc1.to_excel(f"정제/{region}_{detail}.xlsx")
